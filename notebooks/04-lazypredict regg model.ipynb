# %%
import pickle
import os
import pandas as pd

# %%
# Loading Dataset
from sklearn.model_selection import train_test_split

df1 = pd.read_csv('../data/interim/train_MICE_median_ind_QuantileTransformer.csv')
X, y = df1.drop(columns=['Weight', 'Label']), df1['Weight']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=30000)     # about 12%

# %%
os.listdir('../reports/lazypredict/regg/')
# Out:
# ['.ipynb_checkpoints',
#  'dependency.txt',
#  'Lazypredict_regg_model_2_12_10_9_2021.pkl',
#  'predict_2_12_10_9_2021.csv',
#  'train_2_12_10_9_2021.csv']

# %%
# Loading lazypredicr results table:
pred = pd.read_csv("../reports/lazypredict/regg/predict_2_12_10_9_2021.csv")
pred
# Out:
#     Adjusted R-Squared  R-Squared  RMSE  Time Taken
# 0                 0.63       0.63  1.15        9.21
# 1                 0.63       0.63  1.15        4.15
# 2                 0.62       0.62  1.15      242.95
# 3                 0.62       0.62  1.15       55.54
# 4                 0.62       0.62  1.15      282.19
# 5                 0.62       0.62  1.16     1444.73
# 6                 0.61       0.61  1.17    29308.84
# 7                 0.60       0.60  1.18      266.84
# 8                 0.60       0.60  1.18    20098.85
# 9                 0.58       0.58  1.21      103.53
# 10                0.54       0.54  1.27      320.53
# 11                0.48       0.48  1.35        1.05
# 12                0.48       0.48  1.35        0.68
# 13                0.48       0.48  1.35        4.37
# 14                0.48       0.48  1.35        2.95
# 15                0.48       0.48  1.35        4.28
# 16                0.48       0.48  1.35        0.90
# ...

# %%
# Loading saved lazy predict model:

with open('../reports/lazypredict/regg/Lazypredict_regg_model_2_12_10_9_2021.pkl', 'rb') as fp:
    reg = pickle.load(fp)
# Out:
# f:\installationfolder\anaconda\envs\higgs_boson\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
reg.provide_models(X_train, X_test, y_train, y_test)['DecisionTreeRegressor']
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h',
#        'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet',
#        'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_pt_ratio_lep_tau',
#        'DER_met_phi_cent...
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
# ...
