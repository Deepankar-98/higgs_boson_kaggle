# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
## Display all rows:

pd.pandas.set_option('display.max_columns', None)

# %%
# For colab:
# df = pd.read_csv('test_MICE_median_ind_QuantileTransformer.csv')

# For local
df = pd.read_csv('../data/interim/test_MICE_median_ind_QuantileTransformer.csv')

# %% [markdown]
# ## Dropping un-important columns:

# %%
# Dropping the less important feature columns
drop_cols = ['PRI_jet_leading_phi',
 'PRI_jet_subleading_phi',
 'PRI_tau_phi',
 'PRI_met_phi',
 'PRI_lep_phi']

df = df.drop(columns=drop_cols)

# %% [markdown]
# ## Loading saved model:

# %%
import pickle

with open('../models/regg/xgb_without_outliers.pkl', 'rb') as fp:
    xgb = pickle.load(fp)

# %% [markdown]
# ## Predict Weight:

# %%
weight = xgb.predict(df)
df['Weight'] = weight

# %%
df.head()
# Out:
#    DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  \
# 0                     0.870957     -2.216645 -1.119281             -0.247752
# 1                     0.485897      0.537209  0.240473             -0.764985
# 2                     0.207364      0.803335 -0.981127              0.772278
# 3                    -0.356748      0.830878 -0.753776              0.658167
# 4                     0.980058     -0.708379  0.803889             -1.257833
#
#    DER_mass_jet_jet  DER_prodeta_jet_jet  DER_deltar_tau_lep  DER_pt_tot  \
# 0          0.045770             0.314780           -1.760258   -0.628724
# 1         -0.688471             0.732956           -0.447305   -0.710987
# 2          0.723645            -0.682084            0.328223   -0.429568
# 3          0.476624            -0.588021            0.410169   -0.077850
# 4          1.104476             1.008340           -1.564141    2.039303
#
#    DER_pt_ratio_lep_tau  DER_met_phi_centrality  DER_lep_eta_centrality  \
# 0              0.377630               -1.081940               -0.154389
# 1              0.671605               -0.285482               -0.885844
# 2             -0.304482               -1.207532                0.606136
# 3             -0.797044               -0.761353                0.554211
# 4              0.598435               -0.148161               -1.456896
#
#    PRI_tau_pt  PRI_tau_eta  PRI_lep_pt  PRI_lep_eta   PRI_met  PRI_met_sumet  \
# 0   -1.152662    -0.381000   -0.514836    -0.312376  0.559906      -1.058504
# 1   -0.073666    -1.378114    0.723435    -0.078281 -0.689173      -0.033037
# 2    0.744433    -0.203027    0.568913    -0.346188 -0.784166      -0.845672
# 3    0.935067     0.295951    0.118736    -0.166791 -0.466263      -0.158631
# 4    0.682761    -1.156012    1.437480    -1.436244 -0.625119       2.856842
#
#    PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 0    -5.199338           -0.054166            -0.221820
# 1     0.137177            0.161513            -0.513904
# 2    -5.199338           -0.238294            -0.158376
# 3    -5.199338           -0.067167             0.005652
# 4     5.199338            2.163490            -0.889240
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_all_pt  ind_15  \
# 0               0.395689               -0.253346       -5.199338    True
# 1               0.598879               -0.266867        0.114521   False
# 2              -0.213750               -0.154430       -5.199338   False
# 3              -0.438161               -0.013566       -5.199338   False
# 4               2.772217                0.539375        2.834838   False
#
#    ind_40  ind_70    Weight
# 0    True    True  3.969820
# 1   False    True  2.273312
# 2    True    True  1.388584
# 3    True    True  0.306692
# 4   False   False  0.684285

# %%
df.shape
# Out:
# (550000, 27)

# %% [markdown]
# Note in the begining we have dropped the EventId column which is in-correct approach but since we have not shuffled the test dataset, we can add the column from the initial test data

# %% [markdown]
# ## Inserting EventId field:

# %%
test = pd.read_csv('../data/raw/test.csv')
test.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   350000      -999.000                       79.589        23.916     3.036
# 1   350001       106.398                       67.490        87.949    49.994
# 2   350002       117.794                       56.226        96.358     4.137
# 3   350003       135.861                       30.604        97.288     9.104
# 4   350004        74.159                       82.772        58.731    89.646
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0              -999.000          -999.000             -999.000
# 1              -999.000          -999.000             -999.000
# 2              -999.000          -999.000             -999.000
# 3              -999.000          -999.000             -999.000
# 4                 1.347           536.663               -0.339
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 0               0.903       3.036      56.018                 1.536
# 1               2.048       2.679     132.865                 1.777
# 2               2.755       4.137      97.600                 1.096
# 3               2.811       9.104      94.112                 0.819
# 4               1.028      77.213     721.552                 1.713
#
#    DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  PRI_tau_eta  \
# 0                  -1.404                -999.000      22.088       -0.540
# 1                  -1.204                -999.000      30.716       -1.784
# 2                  -1.408                -999.000      46.564       -0.298
# 3                  -1.382                -999.000      51.741        0.388
# 4                  -0.913                   0.004      45.087       -1.548
#
#    PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_met  PRI_met_phi  \
# 0       -0.609      33.930       -0.504       -1.511   48.509        2.022
# 1        3.054      54.574       -0.169        1.795   21.093       -1.138
# 2        3.079      51.036       -0.548        0.336   19.461       -1.868
# 3       -1.408      42.371       -0.295        2.148   25.131        1.172
# 4        1.877      77.252       -1.913        2.838   22.200       -0.231
#
#    PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 0         98.556            0            -999.000             -999.000
# 1        176.251            1              47.575               -0.553
# 2        111.505            0            -999.000             -999.000
# 3        164.707            0            -999.000             -999.000
# 4        869.614            3             254.085               -1.013
#
#    PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0             -999.000               -999.000                -999.000
# 1               -0.849               -999.000                -999.000
# 2             -999.000               -999.000                -999.000
# 3             -999.000               -999.000                -999.000
# 4               -0.334                185.857                   0.335
#
#    PRI_jet_subleading_phi  PRI_jet_all_pt
# 0                -999.000          -0.000
# 1                -999.000          47.575
# 2                -999.000           0.000
# 3                -999.000           0.000
# 4                   2.587         599.213

# %%
df.insert(0, column='EventId', value=test['EventId'])
df.head()
# Out:
#    EventId  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   350000                     0.870957     -2.216645 -1.119281
# 1   350001                     0.485897      0.537209  0.240473
# 2   350002                     0.207364      0.803335 -0.981127
# 3   350003                    -0.356748      0.830878 -0.753776
# 4   350004                     0.980058     -0.708379  0.803889
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0             -0.247752          0.045770             0.314780
# 1             -0.764985         -0.688471             0.732956
# 2              0.772278          0.723645            -0.682084
# 3              0.658167          0.476624            -0.588021
# 4             -1.257833          1.104476             1.008340
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_pt_ratio_lep_tau  \
# 0           -1.760258   -0.628724              0.377630
# 1           -0.447305   -0.710987              0.671605
# 2            0.328223   -0.429568             -0.304482
# 3            0.410169   -0.077850             -0.797044
# 4           -1.564141    2.039303              0.598435
#
#    DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  PRI_tau_eta  \
# 0               -1.081940               -0.154389   -1.152662    -0.381000
# 1               -0.285482               -0.885844   -0.073666    -1.378114
# 2               -1.207532                0.606136    0.744433    -0.203027
# 3               -0.761353                0.554211    0.935067     0.295951
# 4               -0.148161               -1.456896    0.682761    -1.156012
#
#    PRI_lep_pt  PRI_lep_eta   PRI_met  PRI_met_sumet  PRI_jet_num  \
# 0   -0.514836    -0.312376  0.559906      -1.058504    -5.199338
# 1    0.723435    -0.078281 -0.689173      -0.033037     0.137177
# 2    0.568913    -0.346188 -0.784166      -0.845672    -5.199338
# 3    0.118736    -0.166791 -0.466263      -0.158631    -5.199338
# 4    1.437480    -1.436244 -0.625119       2.856842     5.199338
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_subleading_pt  \
# 0           -0.054166            -0.221820               0.395689
# 1            0.161513            -0.513904               0.598879
# 2           -0.238294            -0.158376              -0.213750
# 3           -0.067167             0.005652              -0.438161
# 4            2.163490            -0.889240               2.772217
#
#    PRI_jet_subleading_eta  PRI_jet_all_pt  ind_15  ind_40  ind_70    Weight
# 0               -0.253346       -5.199338    True    True    True  3.969820
# 1               -0.266867        0.114521   False   False    True  2.273312
# 2               -0.154430       -5.199338   False    True    True  1.388584
# 3               -0.013566       -5.199338   False    True    True  0.306692
# 4                0.539375        2.834838   False   False   False  0.684285

# %% [markdown]
# ## Saving test data:

# %%
df.to_csv('../data/processed/test_weight_regg.csv', index=False)
